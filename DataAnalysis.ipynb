# %%
import numpy as np
import sklearn
from scipy import stats
import matplotlib.pyplot as plt
import os
import seaborn as sns
import pandas as pd 

data=pd.read_csv("/content/drive/MyDrive/COLAB_SM/SpineSurgery/xr_data_spine_surgery_wristfracture.csv")
print(data)
# Out:
#       Unnamed: 0  ...                               PATH
# 0              0  ...  E10649388_DX_AP_000007_000001.dcm
# 1              1  ...  E10649388_DX_AP_000006_000001.dcm
# 2              2  ...  E10649388_DX_AP_000008_000001.dcm
# 3              3  ...  E10649388_DX_AP_000009_000001.dcm
# 4              4  ...  E12119821_DX_AP_000007_000001.dcm
# ...          ...  ...                                ...
# 5504        5508  ...   L1481958_CR_AP_000003_000001.dcm
# 5505        5509  ...  L1481958_DOC_NA_000001_000001.dcm
# 5506        5510  ...   L1481958_CR_NA_000001_000001.dcm
# 5507        5511  ...     E6334122_CR__001002_001002.dcm
# 5508        5512  ...     E6334122_CR__001001_001001.dcm
#
# [5509 rows x 11 columns]

# %%
data.head()
# Out:
#    Unnamed: 0  PatientID  ... Manufacturer                               PATH
# 0           0    5324252  ...         Agfa  E10649388_DX_AP_000007_000001.dcm
# 1           1    5324252  ...         Agfa  E10649388_DX_AP_000006_000001.dcm
# 2           2    5324252  ...         Agfa  E10649388_DX_AP_000008_000001.dcm
# 3           3    5324252  ...         Agfa  E10649388_DX_AP_000009_000001.dcm
# 4           4    3110287  ...         Agfa  E12119821_DX_AP_000007_000001.dcm
#
# [5 rows x 11 columns]

# %%
data.shape
# Out:
# (5509, 11)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'PatientID', 'AccessionNumber', 'SeriesNumber',
#        'InstanceNumber', 'Modality', 'ViewPosition', 'PatientSex',
#        'PatientAge', 'Manufacturer', 'PATH'],
#       dtype='object')

# %%
data.describe()
# Out:
#         Unnamed: 0     PatientID   SeriesNumber  InstanceNumber   PatientAge
# count  5509.000000  5.509000e+03    5509.000000     5509.000000  5509.000000
# mean   2756.160828  4.385830e+06    2061.056816       40.399710    54.078599
# std    1591.797836  4.056569e+06   11665.955858      223.003505    18.087352
# min       0.000000  1.728000e+03       1.000000        1.000000     7.000000
# 25%    1378.000000  2.948993e+06       2.000000        1.000000    42.000000
# 50%    2757.000000  4.311782e+06       3.000000        1.000000    56.000000
# 75%    4134.000000  5.924366e+06       6.000000        1.000000    66.000000
# max    5512.000000  1.001226e+08  105636.000000     3004.000000   118.000000

# %%
PID=data['PatientID']
_PID, _IND, _INV, _CNT = np.unique(PID, return_index=True, return_inverse=True, return_counts=True)

# %%
id = 0
print(PID[_IND[id]])
print(_PID[id])
print(_CNT[id])
# Out:
# 1728
# 1728
# 3

# %%
print(data.PatientSex)
# Out:
# 0       F
# 1       F
# 2       F
# 3       F
# 4       M
#        ..
# 5504    M
# 5505    M
# 5506    M
# 5507    M
# 5508    M
# Name: PatientSex, Length: 5509, dtype: object

# %%
_SEX=np.zeros(len(_PID))
_SEX = []
_AGE=np.zeros(len(_PID))
_Manufacture = []
_Modality = []

# %%
for i, ind in enumerate(_IND):
    _SEX.append(data.PatientSex[ind])
    _AGE[i] = data.PatientAge[ind]
    _Manufacture.append(data.Manufacturer[ind])
    _Modality.append(data.Modality[ind])

# %%
sns.distplot(a=_AGE, kde=False, label='Age')

#sns.distplot(a=data['PatientAge'], kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
__sex, __sexcount= np.unique(_SEX, return_counts=True)
print(__sex)
print(__sexcount)
plt.bar(__sex,__sexcount)
plt.show()
# Out:
# ['F' 'M']
# [387 179]

# %%
__manu, __manu_count= np.unique(_Manufacture, return_counts=True)
print(__manu)
print(__manu_count)
plt.bar(__manu,__manu_count)
plt.show()
# Out:
# ['"GE Healthcare"' 'AMICAS-NSC' 'Agfa' 'CARESTREAM HEALTH' 'Canon Inc.'
#  'Carestream Health' 'FUJI PHOTO FILM Co., ltd.,' 'FUJIFILM Corporation'
#  'FUJIFILM Medical Systems USA, Inc.' 'GE Healthcare' 'GE MEDICAL SYSTEMS'
#  'IRAY' 'KONICA MINOLTA' 'Konica Minolta' 'Lexmark' 'LifeImageNotify'
#  'PACSGEAR' 'Philips' 'Philips Medical Systems' 'SIEMENS'
#  'Samsung Electronics' 'Toshiba' 'Varian' 'Visage PR']
# [ 10   2 376   7   2   3   2  30   1  13  23  12   7   2   1  25   1   1
#    8  13   1   2  21   3]

# %%
__modality, __moda_count= np.unique(_Modality, return_counts=True)
print(__modality)
print(__moda_count)
plt.bar(__modality,__moda_count)
plt.show()
# Out:
# ['CR' 'DOC' 'DX' 'PR' 'SC' 'SR']
# [ 79   2 478   3   1   3]

# %%
for i, ind in enumerate(_PID):
    #i=0
    #pid=_PID[i]
    #invID=np.asarray(np.where(_INV==i))
    _pidSet=data.PatientID[_INV==i]
    _vpSet=data.ViewPosition[_INV==i]
    _modalSet=data.Modality[_INV==i]
    _ManuSet=data.Manufacturer[_INV==i]
    #print(_pidSet) 
    #print(_vpSet) 
    #print( _modalSet) 
    #print( _ManuSet)

# %%
print("Number of Patient: %d" % len(_PID) )
print("Number of %s/%s: %d / %d " %(__sex[0], __sex[1], __sexcount[0], __sexcount[1]))
print("Number of Manufacture: ")
for i, name in enumerate(__manu):
    print("\t %s : %d" %(name, __manu_count[i]))
# Out:
# Number of Patient: 566
# Number of F/M: 387 / 179
# Number of Manufacture:
# 	 "GE Healthcare" : 10
# 	 AMICAS-NSC : 2
# 	 Agfa : 376
# 	 CARESTREAM HEALTH : 7
# 	 Canon Inc. : 2
# 	 Carestream Health : 3
# 	 FUJI PHOTO FILM Co., ltd., : 2
# 	 FUJIFILM Corporation : 30
# 	 FUJIFILM Medical Systems USA, Inc. : 1
# 	 GE Healthcare : 13
# 	 GE MEDICAL SYSTEMS : 23
# 	 IRAY : 12
# 	 KONICA MINOLTA : 7
# 	 Konica Minolta : 2
# 	 Lexmark : 1
# 	 LifeImageNotify : 25
# 	 PACSGEAR : 1
# 	 Philips : 1
# 	 Philips Medical Systems : 8
# 	 SIEMENS : 13
# 	 Samsung Electronics : 1
# 	 Toshiba : 2
# 	 Varian : 21
# 	 Visage PR : 3

# %%
# Out:
# Unnamed: 0            0
# PatientID             0
# AccessionNumber       0
# SeriesNumber          0
# InstanceNumber        0
# Modality              0
# ViewPosition       1119
# PatientSex            0
# PatientAge            0
# Manufacturer          3
# PATH                  0
# dtype: int64

# %%
# Out:
# (['Unnamed: 0', 'PatientID', 'SeriesNumber', 'InstanceNumber', 'PatientAge'],
#  ['PATH',
#   'PatientSex',
#   'Manufacturer',
#   'ViewPosition',
#   'AccessionNumber',
#   'Modality'])

# %%
cate=categorical_cols

# %%
# Histogram
sns.distplot(a=data['PatientAge'], kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(PID)
# Out:
# 0       5324252
# 1       5324252
# 2       5324252
# 3       5324252
# 4       3110287
#          ...
# 5504    3911497
# 5505    3911497
# 5506    3911497
# 5507    5536283
# 5508    5536283
# Name: PatientID, Length: 5509, dtype: int64

# %%
print(_IND)
# Out:
# [370 370 370 ... 243 388 388]

# %%
a = {}
a['asdf'] = 0

print(a)
# Out:
# {('asdf', 'agg'): 0}

# %%
PID=data['PatientID']
_PID, _IND, _CNT = np.unique(PID, return_index=True, return_counts=True)

# %%
id = 0
print(PID[_IND[id]])
print(_PID[id])
print(_CNT[id])
# Out:
# 1728
# 1728
# 3

# %%
tmp2, _, tmp5 = np.unique(tmp, unique_indices=True, return_counts=True)

# %%
print(tmp2)
print(tmp5)
# Out:
# ['F' 'M']
# [3748 1761]

# %%
PSex=data['PatientSex']
print(PSex)
PSex.shape
dict((x, data.count(x)) for x in PSex)
# Out:
# 0       F
# 1       F
# 2       F
# 3       F
# 4       M
#        ..
# 5504    M
# 5505    M
# 5506    M
# 5507    M
# 5508    M
# Name: PatientSex, Length: 5509, dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#
# KeyError: 'F'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-392fc63eedb1> in <module>()
#       2 print(PSex)
#       3 PSex.shape
# ----> 4 dict((x, data.count(x)) for x in PSex)
#
# <ipython-input-14-392fc63eedb1> in <genexpr>(.0)
#       2 print(PSex)
#       3 PSex.shape
# ----> 4 dict((x, data.count(x)) for x in PSex)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in count(self, axis, level, numeric_only)
#    8457         Myla      1
#    8458         """
# -> 8459         axis = self._get_axis_number(axis)
#    8460         if level is not None:
#    8461             return self._count_level(level, axis=axis, numeric_only=numeric_only)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
# --> 370             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     371
#     372     @classmethod
#
# ValueError: No axis named F for object type DataFrame

# %%
	PatientAge	Manufacturer
